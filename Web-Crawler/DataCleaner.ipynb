# %%
from mtgsdk import Card
import pandas as pd
import numpy as np

# %%
with open('Data_set_All.json', 'r') as f:
    data = json.load(f)
df1 = pd.read_json(data)

# %%
selector_type='competitive-modern'
selected_df=df1.T[df1.T['Play Type'].str.contains(selector_type)]

# %%
total_cards=list(zip(selected_df['Card Name'],selected_df['Card Count']))

# %%
list(zip(*list(zip(*total_cards[0]))[0]))
# Out:
# [('Arclight Phoenix', '4'), ('Bedlam Reveler', '4'), ('Thing in the Ice', '4')]

# %%
len(total_cards)
# Out:
# 8780

# %%
deck_list=[]
name_count=[]
for i in range(len(total_cards)):
    tmp=list(zip(*total_cards[i]))
    deck_list.append(tmp)
    for j in range(len(tmp)):
        name_count.append(list(zip(*deck_list[i][j])))
num_decks=len(deck_list)

# %%
flat_name_count=[item for sublist in name_count for item in sublist]
matching = [s for s in flat_name_count if "Arclight Phoenix" in s]

# %%
group_name_count=[]
temp_list=set(flat_name_count[:])
for group in temp_list:
    name=group[0]
    number=int(group[1])
    matching = [s for s in temp_list if name in s]
    for subgroup in matching:
        number+=int(subgroup[1])
        
    tmp=[name,number]
    group_name_count.append(tmp)

# %%
selected_cards=pd.DataFrame(group_name_count)
name_list=list(selected_cards[0])
count_list=list(selected_cards[1])

# %%
all_name=[]
all_mana_cost=[]
all_cmc=[]
all_type=[]
all_colors=[]
all_rarity=[]
all_number=[]
all_power=[]
all_toughness=[]
all_id=[]
all_win_card=[]
for card in cards:
    all_name.append(card.name)
    all_mana_cost.append(card.mana_cost)
    all_cmc.append(card.cmc)
    all_type.append(card.type)
    all_colors.append(card.colors)
    all_rarity.append(card.rarity)
    all_number.append(card.number)
    all_power.append(card.power)
    all_toughness.append(card.toughness)
    all_id.append(card.id)
    if card.name in name_list:
        all_win_card.append(1)
        print(card.name)
    else:
        all_win_card.append(0)
        print('no')
# Out:
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ...
